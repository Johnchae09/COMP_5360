# %%
import os
import glob
import pandas as pd
import re

main_directory = os.path.normpath(os.getcwd() + os.sep + os.pardir)
data_directory = os.path.join(main_directory, 'TeamStats')
file_names = [f for f in os.listdir(data_directory) if os.path.isfile(os.path.join(data_directory, f))]
file_names
# Out:
# ['2001Playoffs.csv',
#  '2000Def.csv',
#  '2012Def.csv',
#  '2020Off.csv',
#  '2020Adv.csv',
#  '2014Playoffs.csv',
#  '2008Playoffs.csv',
#  '2004Off.csv',
#  '2004Adv.csv',
#  '2008Off.csv',
#  '2008Adv.csv',
#  '2016Off.csv',
#  '2016Adv.csv',
#  '2011Playoffs.csv',
#  '2022Off.csv',
#  '2022Adv.csv',
#  '.DS_Store',
#  '2014Off.csv',
#  '2014Adv.csv',
#  '2023Playoffs.csv',
#  '2006Off.csv',
#  '2006Adv.csv',
#  '2018Off.csv',
#  '2018Adv.csv',
#  '2018Playoffs.csv',
#  '2010Def.csv',
#  '2004Playoffs.csv',
#  '2002Def.csv',
#  '2002Adv.csv',
#  '2002Off.csv',
#  '2007Playoffs.csv',
#  '2010Adv.csv',
#  '2010Off.csv',
#  '2006Def.csv',
#  '2018Def.csv',
#  '2014Def.csv',
#  '2020Playoffs.csv',
#  '2022Def.csv',
#  '2012Playoffs.csv',
#  '2008Def.csv',
#  '2016Def.csv',
#  '2004Def.csv',
#  '2017Playoffs.csv',
#  '2020Def.csv',
#  '2012Adv.csv',
#  '2012Off.csv',
#  '2002Playoffs.csv',
#  '2000Adv.csv',
#  '2000Off.csv',
#  '2005Adv.csv',
#  '2005Off.csv',
#  '2017Adv.csv',
# ...

# %%
#lets read in 2000 def, adv,off, and playoffs


df_df = pd.read_csv(os.path.join(data_directory, '2000Def.csv'))
df_adv = pd.read_csv(os.path.join(data_directory, '2000Adv.csv'),header=1)
df_off = pd.read_csv(os.path.join(data_directory, '2000Off.csv'))
df_play = pd.read_csv(os.path.join(data_directory, '2000Playoffs.csv'),header=1)

# %%
df_df.head(10)
# Out:
#      Rk                  Team▲   G     MP    FG   FGA    FG%   3P   3PA  \
# 0   1.0          Atlanta Hawks  82  241.8  39.2  86.1  0.455  4.5  12.4
# 1   2.0         Boston Celtics  82  240.6  36.1  76.9  0.470  4.4  12.1
# 2   3.0     Charlotte Hornets*  82  241.2  37.2  83.1  0.448  5.0  13.2
# 3   4.0          Chicago Bulls  82  241.5  35.6  78.0  0.456  4.4  12.8
# 4   5.0    Cleveland Cavaliers  82  242.1  36.4  82.1  0.443  5.1  15.0
# 5   6.0       Dallas Mavericks  82  240.6  39.3  86.0  0.457  5.2  15.2
# 6   7.0         Denver Nuggets  82  242.1  38.2  84.8  0.450  4.9  13.7
# 7   8.0       Detroit Pistons*  82  241.8  38.0  81.8  0.465  5.6  15.0
# 8   9.0  Golden State Warriors  82  240.9  38.6  82.6  0.467  5.2  14.2
# 9  10.0        Houston Rockets  82  241.8  39.3  86.3  0.456  4.3  12.1
#
#      3P%  ...    FT%   ORB   DRB   TRB   AST   STL  BLK   TOV    PF    PTS
# 0  0.367  ...  0.769  12.8  30.2  43.0  23.0   8.0  4.9  12.2  22.3   99.7
# ...

# %%
df_adv.head(10)
# Out:
#      Rk                  Team▲   Age     W     L  PW  PL   MOV   SOS   SRS  \
# 0   1.0          Atlanta Hawks  27.6  28.0  54.0  26  56 -5.38 -0.04 -5.41
# 1   2.0         Boston Celtics  25.4  35.0  47.0  39  43 -0.76 -0.24 -1.00
# 2   3.0     Charlotte Hornets*  28.7  49.0  33.0  49  33  2.67 -0.34  2.33
# 3   4.0          Chicago Bulls  26.0  17.0  65.0  15  67 -9.40  0.17 -9.23
# 4   5.0    Cleveland Cavaliers  27.2  32.0  50.0  31  51 -3.50 -0.14 -3.64
# 5   6.0       Dallas Mavericks  26.3  40.0  42.0  39  43 -0.57  0.29 -0.29
# 6   7.0         Denver Nuggets  25.9  35.0  47.0  35  47 -2.12  0.36 -1.76
# 7   8.0       Detroit Pistons*  28.3  42.0  40.0  45  37  1.44 -0.31  1.13
# 8   9.0  Golden State Warriors  26.9  19.0  63.0  20  62 -8.27  0.64 -7.63
# 9  10.0        Houston Rockets  26.3  34.0  48.0  39  43 -0.87  0.30 -0.57
#
#    ...  FT/FGA  Unnamed: 22  eFG%.1  TOV%.1  DRB%  FT/FGA.1  Unnamed: 27  \
# ...

# %%
df_off.head(10)
# Out:
#      Rk                  Team▲   G     MP    FG   FGA    FG%   3P   3PA  \
# 0   1.0          Atlanta Hawks  82  241.8  36.6  83.0  0.441  3.1   9.9
# 1   2.0         Boston Celtics  82  240.6  37.2  83.9  0.444  5.1  15.4
# 2   3.0     Charlotte Hornets*  82  241.2  35.8  79.7  0.449  4.1  12.2
# 3   4.0          Chicago Bulls  82  241.5  31.3  75.4  0.415  4.1  12.6
# 4   5.0    Cleveland Cavaliers  82  242.1  36.3  82.1  0.442  4.2  11.2
# 5   6.0       Dallas Mavericks  82  240.6  39.0  85.9  0.453  6.3  16.2
# 6   7.0         Denver Nuggets  82  242.1  37.3  84.3  0.442  5.7  17.0
# 7   8.0       Detroit Pistons*  82  241.8  37.1  80.9  0.459  5.4  14.9
# 8   9.0  Golden State Warriors  82  240.9  36.5  87.1  0.420  4.2  13.0
# 9  10.0        Houston Rockets  82  241.8  36.6  81.3  0.450  7.1  19.8
#
#      3P%  ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  0.317  ...  0.743  14.0  31.3  45.3  18.9  6.1  5.6  15.4  21.0   94.3
# ...

# %%
df_play.head(10)
# Out:
#      Rk                    Team   Age     W     L   W/L%  PW  PL   ORtg  \
# 0   1.0  Portland Trail Blazers  30.0  10.0   6.0  0.625  11   5  107.7
# 1   2.0              Miami Heat  29.6   6.0   4.0  0.600   6   4   97.4
# 2   3.0          Indiana Pacers  30.9  13.0  10.0  0.565  14   9  109.7
# 3   4.0      Los Angeles Lakers  29.3  15.0   8.0  0.652  13  10  110.1
# 4   5.0         Milwaukee Bucks  27.6   2.0   3.0  0.400   3   2  107.5
# 5   6.0         New York Knicks  29.7   9.0   7.0  0.563   7   9   99.8
# 6   7.0     Seattle Supersonics  27.9   2.0   3.0  0.400   2   3  104.5
# 7   8.0       San Antonio Spurs  31.0   1.0   3.0  0.250   2   2   90.0
# 8   9.0      Philadelphia 76ers  27.6   5.0   5.0  0.500   5   5  106.5
# 9  10.0  Minnesota Timberwolves  26.6   1.0   3.0  0.250   2   2  103.4
#
#     DRtg  ...  Unnamed: 15   eFG%  TOV%  ORB%  FT/FGA  Unnamed: 20  eFG%.1  \
# 0  102.2  ...          NaN  0.481  12.9  25.9   0.303          NaN   0.478
# ...

# %%
df_play.shape
# Out:
# (17, 25)

# %%
#seperate file names
off_files = [file for file in file_names if 'Off.csv' in file]
def_files = [file for file in file_names if 'Def.csv' in file]
adv_files = [file for file in file_names if 'Adv.csv' in file]
playoff_files = [file for file in file_names if 'Playoffs.csv' in file]

off_files = sorted(off_files)
def_files = sorted(def_files)
adv_files = sorted(adv_files)
playoff_files = sorted(playoff_files)

#initalize column headers and check if all file format is the same
off_header = df_off.columns
def_header = df_df.columns
adv_header = df_adv.columns
play_header = df_play.columns
off_header
# Out:
# Index(['Rk', 'Team▲', 'G', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
#        '2PA', '2P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
#initalize some dataframe
df_offensive = pd.DataFrame()
df_defensive = pd.DataFrame()
df_playoff = pd.DataFrame()
df_advance = pd.DataFrame()


for i in range(len(off_files)):
    df = pd.read_csv(os.path.join(data_directory, off_files[i]))
    if df.columns.equals(off_header):
        df_offensive = pd.concat([df_offensive,df])
    else:
        print('this file header didnt match: ',off_files[i])
    
    df = pd.read_csv(os.path.join(data_directory, def_files[i]))
    if df.columns.equals(def_header):
        df_defensive = pd.concat([df_defensive,df])
    else:
        print('this file header didnt match: ',def_files[i])
        
    df = pd.read_csv(os.path.join(data_directory, adv_files[i]),header=1)
    if df.columns.equals(adv_header):
        df_advance = pd.concat([df_advance,df])
    else:
        print('this file header didnt match: ',adv_files[i])
        
    df = pd.read_csv(os.path.join(data_directory, playoff_files[i]),header=1)
    if df.columns.equals(play_header):
        df_playoff = pd.concat([df_playoff,df])
    else:
        print('this file header didnt match: ',playoff_files[i])

# %%
df_advance.shape
# Out:
# (739, 31)

# %%
df_playoff.shape
# Out:
# (412, 25)

# %%
df_defensive.shape
# Out:
# (739, 25)

# %%
df_offensive.shape
# Out:
# (739, 25)

# %%
df_advance.to_csv('team_adv.csv',header=True,index=False)
df_playoff.to_csv('team_playoff.csv',header=True,index=False)
df_defensive.to_csv('team_defensive.csv',header=True,index=False)
df_offensive.to_csv('team_offensive.csv',header=True,index=False)
